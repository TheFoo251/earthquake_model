# %%
from fastai.data.all import *
from fastai.vision.all import *

# %%
path = Path("../patch_data_256")
path.ls()
# Out:
# (#3) [Path('../patch_data_256/codes.txt'),Path('../patch_data_256/images'),Path('../patch_data_256/targets')]

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str)
codes
# Out:
# array(['NoDamage', 'MinorDamage', 'MajorDamage', 'Destroyed'],
#       dtype='<U11')

# %%
fnames = get_image_files(path/"images")
fnames[0]
# Out:
# Path('../patch_data_256/images/mexico-earthquake_00000169_post_disaster--patch00310.png')

# %%
(path/"targets").ls()[0]
# Out:
# Path('../patch_data_256/targets/mexico-earthquake_00000169_post_disaster--patch00310.png')

# %%
def label_func(fn): return path/"targets"/f"{fn.stem}{fn.suffix}"

# %%
dls = SegmentationDataLoaders.from_label_func(
    path, bs=8, fnames = fnames, label_func = label_func, codes=codes
)

# %%
dls.show_batch(max_n=4)

# %%
learn = unet_learner(dls, resnet34)
learn.fine_tune(6)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 learn = unet_learner(dls, resnet34)
#       2 learn.fine_tune(6)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/vision/learner.py:278, in unet_learner(dls, arch, normalize, n_out, pretrained, weights, config, loss_func, opt_func, lr, splitter, cbs, metrics, path, model_dir, wd, wd_bn_bias, train_bn, moms, **kwargs)
#     275 if normalize: _add_norm(dls, meta, pretrained, n_in)
#     277 n_out = ifnone(n_out, get_c(dls))
# --> 278 assert n_out, "`n_out` is not defined, and could not be inferred from data, set `dls.c` or pass `n_out`"
#     279 img_size = dls.one_batch()[0].shape[-2:]
#     280 assert img_size, "image size could not be inferred from data"
#
# AssertionError: `n_out` is not defined, and could not be inferred from data, set `dls.c` or pass `n_out`

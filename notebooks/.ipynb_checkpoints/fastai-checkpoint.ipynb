# %% [markdown]
# https://fastai1.fast.ai/troubleshoot.html

# %%
#import os
#os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
import torch
from fastai.data.all import *
from fastai.vision.all import *
from patchify import patchify

#torch.device("cpu")

#fastai.defaults.device = "cpu"
#defaults.device = "cpu"
#!export CUDA_VISIBLE_DEVICES=""

# %% [markdown]
# [https://walkwithfastai.com/Segmentation]

# %%
path = Path("../data/post-disaster/")
path.ls()
# Out:
# (#4) [Path('../data/post-disaster/codes.txt'),Path('../data/post-disaster/images'),Path('../data/post-disaster/models'),Path('../data/post-disaster/targets')]

# %%
fnames = get_image_files(path/"images")
fnames
# Out:
# (#193) [Path('../data/post-disaster/images/mexico-earthquake_00000184_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000119_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000150_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000148_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000005_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000073_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000138_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000157_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000100_post_disaster.png'),Path('../data/post-disaster/images/mexico-earthquake_00000179_post_disaster.png')...]

# %%
(path/"targets").ls()
# Out:
# (#193) [Path('../data/post-disaster/targets/mexico-earthquake_00000016_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000073_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000153_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000149_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000078_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000115_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000086_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000169_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000070_post_disaster_target.png'),Path('../data/post-disaster/targets/mexico-earthquake_00000059_post_disaster_target.png')...]

# %%
# get a test image
im = PILImage.create(fnames[17]); im
ten = tensor(im).permute(2, 0, 1)
# Shape is BxCxHxW
ten.shape
# Out:
# torch.Size([3, 1024, 1024])

# %%
show_image(ten)
# Out:
# <Axes: >

# %%
# https://discuss.pytorch.org/t/split-an-image-into-a-2-by-2-grid/189895

row_length, col_length = (256,256)
grid_length = 4
patches = (ten
               .unfold(1,row_length,col_length)
               .unfold(2,row_length,col_length)
               .reshape(3,grid_length**2,row_length,col_length)
               .permute(1,0,2,3))

# %%
patches.shape
# Out:
# torch.Size([16, 3, 256, 256])

# %%
 # show_image_batch(([patch for patch in patches]), items=16)
# visualize it later... for now include it in the pipeline

# %%
def label_func(fn): return path/"targets"/f"{fn.stem}_target{fn.suffix}"

# %%
codes = ["Background", "NoDamage", "MinorDamage", "MajorDamage", "Destroyed"]

# %%
dls = SegmentationDataLoaders.from_label_func(
    path,
    bs=8,
    fnames = fnames,
    label_func = label_func,
    codes = codes,
    # item_tfms = Resize(1024)
)
#dls.vocab = codes

# %%
# dls.c

# %%
dls.show_batch(max_n=8)

# %%
learn = unet_learner(
    dls, 
    resnet18, 
    metrics=DiceMulti(axis=1), 
    self_attention=True, 
    act_cls=Mish,
    loss_func = DiceLoss(),
    pretrained=True
)
# learn.summary()

# %%
lr = learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
lr = lr[0]; lr
# Out:
# 0.0012022644514217973

# %%
# automatically does applies all of Leslie's tricks-- 1cycle, freezing, discrinatory lr
learn.fine_tune(epochs=10, base_lr=lr, freeze_epochs=2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.657774</td>
#       <td>1.592957</td>
#       <td>0.638001</td>
#       <td>06:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.954933</td>
#       <td>1.770467</td>
#       <td>0.631060</td>
#       <td>06:41</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='442' class='' max='1253' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.28% [442/1253 02:16&lt;04:09 1.4667]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # automatically does applies all of Leslie's tricks-- 1cycle, freezing, discrinatory lr
# ----> 2 learn.fine_tune(epochs=10, base_lr=lr, freeze_epochs=2)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/callback/schedule.py:168, in fine_tune(self, epochs, base_lr, freeze_epochs, lr_mult, pct_start, div, **kwargs)
#     166 base_lr /= 2
#     167 self.unfreeze()
# --> 168 self.fit_one_cycle(epochs, slice(base_lr/lr_mult, base_lr), pct_start=pct_start, div=div, **kwargs)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/callback/schedule.py:119, in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt, start_epoch)
#     116 lr_max = np.array([h['lr'] for h in self.opt.hypers])
#     117 scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     118           'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 119 self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:264, in Learner.fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     262 self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     263 self.n_epoch = n_epoch
# --> 264 self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:199, in Learner._with_events(self, f, event_type, ex, final)
#     198 def _with_events(self, f, event_type, ex, final=noop):
# --> 199     try: self(f'before_{event_type}');  f()
#     200     except ex: self(f'after_cancel_{event_type}')
#     201     self(f'after_{event_type}');  final()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:253, in Learner._do_fit(self)
#     251 for epoch in range(self.n_epoch):
#     252     self.epoch=epoch
# --> 253     self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:199, in Learner._with_events(self, f, event_type, ex, final)
#     198 def _with_events(self, f, event_type, ex, final=noop):
# --> 199     try: self(f'before_{event_type}');  f()
#     200     except ex: self(f'after_cancel_{event_type}')
#     201     self(f'after_{event_type}');  final()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:247, in Learner._do_epoch(self)
#     246 def _do_epoch(self):
# --> 247     self._do_epoch_train()
#     248     self._do_epoch_validate()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:239, in Learner._do_epoch_train(self)
#     237 def _do_epoch_train(self):
#     238     self.dl = self.dls.train
# --> 239     self._with_events(self.all_batches, 'train', CancelTrainException)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:199, in Learner._with_events(self, f, event_type, ex, final)
#     198 def _with_events(self, f, event_type, ex, final=noop):
# --> 199     try: self(f'before_{event_type}');  f()
#     200     except ex: self(f'after_cancel_{event_type}')
#     201     self(f'after_{event_type}');  final()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:205, in Learner.all_batches(self)
#     203 def all_batches(self):
#     204     self.n_iter = len(self.dl)
# --> 205     for o in enumerate(self.dl): self.one_batch(*o)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:235, in Learner.one_batch(self, i, b)
#     233 b = self._set_device(b)
#     234 self._split(b)
# --> 235 self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:199, in Learner._with_events(self, f, event_type, ex, final)
#     198 def _with_events(self, f, event_type, ex, final=noop):
# --> 199     try: self(f'before_{event_type}');  f()
#     200     except ex: self(f'after_cancel_{event_type}')
#     201     self(f'after_{event_type}');  final()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:223, in Learner._do_one_batch(self)
#     221 self('after_loss')
#     222 if not self.training or not len(self.yb): return
# --> 223 self._do_grad_opt()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:212, in Learner._do_grad_opt(self)
#     210 def _do_grad_opt(self):
#     211     self._with_events(self._backward, 'backward', CancelBackwardException)
# --> 212     self._with_events(self._step, 'step', CancelStepException)
#     213     self.opt.zero_grad()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:199, in Learner._with_events(self, f, event_type, ex, final)
#     198 def _with_events(self, f, event_type, ex, final=noop):
# --> 199     try: self(f'before_{event_type}');  f()
#     200     except ex: self(f'after_cancel_{event_type}')
#     201     self(f'after_{event_type}');  final()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/learner.py:208, in Learner._step(self)
# --> 208 def _step(self): self.opt.step()
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/optimizer.py:111, in Optimizer.step(self, closure)
#     109 if closure is not None: raise NotImplementedError("fastai optimizers currently do not support closure")
#     110 for p,pg,state,hyper in self.all_params(with_grad=True):
# --> 111     for cb in self.cbs: state = _update(state, cb(p, **{**state, **hyper}))
#     112     self.state[p] = state
#
# File ~/miniforge3/envs/fastai/lib/python3.11/site-packages/fastai/optimizer.py:224, in adam_step(p, lr, mom, step, sqr_mom, grad_avg, sqr_avg, eps, **kwargs)
#     222 debias1 = debias(mom,     1-mom,     step)
#     223 debias2 = debias(sqr_mom, 1-sqr_mom, step)
# --> 224 p.data.addcdiv_(grad_avg, (sqr_avg/debias2).sqrt() + eps, value = -lr / debias1)
#     225 return p
#
# KeyboardInterrupt:

# %%
learn.show_results(max_n=8)
